# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt') 

results = model.train(
    data='data.yaml', 
    epochs=50,  
    imgsz=640,
    batch=8,
    workers=0,
    name='pothole_v2' 
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.252 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.251 🚀 Python-3.10.12 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# ...
